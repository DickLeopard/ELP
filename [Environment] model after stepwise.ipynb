# %%
# %matplotlib inline
from collections import defaultdict
import json

import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from matplotlib import rcParams
import matplotlib.cm as cm
import matplotlib as mpl
import statsmodels.api as sm
from sklearn.linear_model import LinearRegression


rcParams['figure.figsize'] = (10, 6)
rcParams['figure.dpi'] = 150
rcParams['lines.linewidth'] = 2
rcParams['font.size'] = 14
rcParams['font.family'] = 'StixGeneral'

# %%
model_data = pd.read_csv("./Data/env_step.csv")
model_data.tail(5)
# Out:
#       Date  Environment  OECD_Maj6  Econ_Sent  fed_funds  Water_Avg  unemploy  \
# 74  3 2014       0.0363   0.001543     0.1273   0.511628      0.033  6.633333
# 75  4 2014       0.0170   0.001620     0.1352   0.545455      0.023  6.500000
# 76  5 2014       0.0293   0.001732     0.1353   0.650000      0.022  6.366667
# 77  6 2014       0.0323   0.001776     0.1177   0.800000      0.041  6.200000
# 78  7 2014       0.0600   0.001555     0.0945   0.965517      0.056  6.200000
#
#        ISM2     JPM2  water_supply  fed_funds2    trade2  water_supply2  \
# 74  53.3000  2795.24      0.848864    0.261763  0.010424       0.720570
# 75  54.8667  2756.25      0.878105    0.297521  0.007157       0.771068
# 76  55.8333  2717.54      0.925569    0.422500  0.004816       0.856677
# 77  57.0000  2724.84      0.956403    0.640000  0.001109       0.914706
# 78  58.1000  2742.62      0.962642    0.932224  0.003215       0.926679
#
#      EURO_CCI  trade_balance  gas_station_trade     ISM1
# 74 -10.200000         0.1021           0.976083  58.5000
# 75  -8.333333         0.0846           0.972487  58.5000
# 76  -7.733333         0.0694           0.993388  58.1667
# 77  -7.666667         0.0333           1.002265  59.1667
# 78  -8.633333         0.0567           0.997699  58.5000

# %%
variable_list = ["OECD_Maj6","Econ_Sent","fed_funds","Water_Avg","unemploy","ISM2","JPM2","water_supply","fed_funds2","trade2","water_supply2","EURO_CCI","trade_balance","gas_station_trade","ISM1"]

# %%
reg = LinearRegression()
lag = 6
for i in range(24)[14:24]:
    N = 3*i
    x_train = model_data[variable_list][:N]
    y_train = model_data[["Environment"]][lag:N+lag]
    x_test = model_data[variable_list][N:-lag-1]
    y_test = model_data[["Environment"]][N+lag:-1]
    reg.fit(x_train, y_train)
    predicted_y = reg.predict(x_test)
    time = range(73)[N+1:73]
    plt.plot(time,predicted_y)

# %%
r_square=[]
y_hat=[]
training_error=[]
test_error=[]
reg = LinearRegression()
lag = 6
p = len(variable_list)
for i in range(73)[1:]:
    x_train = model_data[variable_list][:-i-lag].values
    y_train = model_data[["Environment"]][lag:-i].values
    x_test = model_data[variable_list][-lag-i:-lag-i+1].values
    if i == 1:
        y_test = model_data[["Environment"]][-i:].values
    else: 
        y_test = model_data[["Environment"]][-i:-i+1].values
    x_validation = model_data[variable_list][-i-lag:-lag].values
    y_validation = model_data[["Environment"]][-i:].values
    reg.fit(x_train, y_train)
    predicted_y = reg.predict(x_test)
    y_hat.append(predicted_y)
    rs = reg.score(x_train,y_train)
    adjusted_rs = 1-(1-rs)*(len(x_train)-1)/(len(x_train)-p-1)
    r_square.append(adjusted_rs)
    y_training_fit = reg.predict(x_train)
    y_test_fit = reg.predict(x_validation)
    training_error.append(np.sqrt(np.mean((y_train-y_training_fit)**2)))
    test_error.append(np.sqrt(np.mean((y_validation-y_test_fit)**2)))
y_hat = y_hat[::-1] # 37...73
r_square = r_square[::-1]
training_error = training_error[::-1]
test_error = test_error[::-1]
y = model_data[["Environment"]][-len(y_hat):].values
t = range(74)[-len(y_hat):]
residual = map(lambda x, y: x - y, y, y_hat)
training_size = range(73)[-len(y_hat):]
for x in [y,y_hat,residual]:
    for index, item in enumerate(x):
        x[index] = float(item)

# %%
plt.plot(t,y,label="y")
plt.plot(t,y_hat,label="y_hat")
plt.legend()

# %%
plt.scatter(residual,y_hat)
plt.xlabel("fitted value", size=18)
plt.ylabel("residual",size=18)
plt.title("residual vs. fitted value",size=18)

# %%
plt.plot(t,r_square)
plt.xlabel("training set size",size=18)
plt.ylabel("adjusted R square", size=18)
plt.title("adjusted R square",size=18)

# %%
plt.plot(training_size,training_error,label='training error')
plt.plot(training_size,test_error,label='test error')
plt.xlabel("training set size",size=18)
plt.ylabel("error",size=18)
plt.legend()
