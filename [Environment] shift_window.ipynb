# %%
# %matplotlib inline
from collections import defaultdict
import json

import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import pandas as pd

from matplotlib import rcParams
import matplotlib.cm as cm
import matplotlib as mpl
import statsmodels.api as sm
from sklearn.linear_model import LinearRegression

#colorbrewer2 Dark2 qualitative color table
dark2_colors = [(0.10588235294117647, 0.6196078431372549, 0.4666666666666667),
                (0.8509803921568627, 0.37254901960784315, 0.00784313725490196),
                (0.4588235294117647, 0.4392156862745098, 0.7019607843137254),
                (0.9058823529411765, 0.1607843137254902, 0.5411764705882353),
                (0.4, 0.6509803921568628, 0.11764705882352941),
                (0.9019607843137255, 0.6705882352941176, 0.00784313725490196),
                (0.6509803921568628, 0.4627450980392157, 0.11372549019607843)]

rcParams['figure.figsize'] = (10, 6)
rcParams['figure.dpi'] = 150
rcParams['axes.color_cycle'] = dark2_colors
rcParams['lines.linewidth'] = 2
rcParams['axes.facecolor'] = 'white'
rcParams['font.size'] = 14
rcParams['patch.edgecolor'] = 'white'
rcParams['patch.facecolor'] = dark2_colors[0]
rcParams['font.family'] = 'StixGeneral'

# %%
model_data = pd.read_csv("./Data/environment_regression.csv")
model_data.tail(5)
# Out:
#       Date  Environment  Water_Avg  JPM_Global_PMI  OECD_Maj6  trade_balance  \
# 74  3 2014       0.0363     0.0327           52.87   0.001543         0.1021
# 75  4 2014       0.0170     0.0230           52.50   0.001620         0.0846
# 76  5 2014       0.0293     0.0217           52.13   0.001732         0.0694
# 77  6 2014       0.0323     0.0407           52.20   0.001776         0.0333
# 78  7 2014       0.0600     0.0560           52.37   0.001555         0.0567
#
#     Econ_Sent  Dollar Index   ISM1  UDS/CNY   ISM2  EURO CCI  unemploy  \
# 74     0.1273         79.83  53.93    6.163  53.30    -12.67    0.0657
# 75     0.1352         80.06  54.47    6.134  54.87    -11.23    0.0643
# 76     0.1353         79.91  55.20    6.122  55.83    -10.20    0.0623
# 77     0.1177         80.58  57.13    6.119  57.00     -8.33    0.0620
# 78     0.0945         81.37  57.57    6.116  58.10     -7.73    0.0613
#
#     fx_index_1  fx_index_2  Water2     JPM2     OECD2  trade2   Econ2
# ...

# %%
variable_list=["Water_Avg","JPM_Global_PMI","OECD_Maj6","trade_balance","Econ_Sent","Dollar Index","ISM1","UDS/CNY","ISM2","EURO CCI","unemploy","fx_index_1","fx_index_2","Water2","JPM2","OECD2","trade2","Econ2"]

# %%
r_square=[]
reg = LinearRegression()
lag = 6
p = len(variable_list)
window_width = w = 36
for i in range(w+2)[1:]:
    x_train = model_data[variable_list][i-1:i-1+w].values
    y_train = model_data[["Environment"]][i-1+lag:i-1+w+lag].values
    reg.fit(x_train, y_train)
    rs = reg.score(x_train,y_train)
    adjusted_rs = 1-(1-rs)*(len(x_train)-1)/(len(x_train)-p-1)
    r_square.append(adjusted_rs)
t = range(w+2)[1:]

# %%
plt.plot(t,r_square,label="adjusted R square")
plt.xlabel("training set start point", size=18)
plt.ylabel("adjusted R square", size=18)
plt.title("shift window adjusted R square, window width=36")
plt.legend()
